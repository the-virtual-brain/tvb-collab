# %% [markdown]
# <h1 align="center"><font size="7" face="arial" color="#2C5453">Hands-On</font></h1>
#
# <h1 align="center"><font size="7" face="arial" color="#2C5453">Generate a virtual epileptic patient</font></h1>

# %% [markdown]
# <h2 align="center"><font size="5" face="arial">11<sup>th</sup> March 2020</font></h2>

# %% [markdown]
# <h3 align="center"><span style="font-weight:normal"><font size="5" face="arial">Julie Courtiol</font></span></h3>
# <h3 align="center"><span style="font-weight:normal"><font size="3" face="arial">Charité Universitätsmedizin Berlin, Dept of Neurol, Brain Simulation Section, Berlin, Germany</font></span></h3>
#
# <h3 align="center"><span style="font-weight:normal"><font size="3" face="arial"><a href="mailto:julie.courtiol@charite.de">julie.courtiol@charite.de</a></font></span></h3>

# %% [markdown]
# <h1><font size="6" face="arial" color="#386766">Context</font></h1>
#
# ---
#
# <p><div style="text-align: justify"><font size="4.5" face="time roman">
# <ul>
# <li><b>Epilepsy</b> is one of the most common neurological disorder that is defined by the occurrence of repetitive unexpected seizures. These epileptic seizures, characterized as abnormal synchronization of neural activities, originate in a specific set of brain regions, known as the <b>Epileptique Zone (EZ)</b>, and propagate to other regions, the <b>Propagation Zone (PZ)</b>, through inter-regional structural interactions, i.e., individual brain connectome, and produce various ictal symptoms depending on the recruited brain regions.</li><br>
#
# <li>Approximately 30% of patients suffering from focal seizures are refractory to medication, hence <b>surgical intervention</b>, which consists in the removal of the EZ, is considered as an alternative treatment.</li><br>
# </ul></font></div></p>
#
# <br><h1><font size="6" face="arial" color="#386766">Objectives</font></h1>
#
# ---
#
# <p><div style="text-align: justify"><font size="4.5" face="time roman">The main goal of this hands-on is to provide a clear understanding of <b>how we can reproduce clinically relevant scenarios</b> such as:
# <ul>
# <li>the modelisation of the <b>propagation of an epileptic seizure</b> in a human brain,</li>
# <li>the <b>surgical resection</b> of the Epileptogenic Zone,</li>
# <li>and the <b>electrical stimulation</b> of a brain region that can trigger a seizure.</li>
# </ul></font></div></p>
#
# <br><h1><font size="6" face="arial" color="#386766">How to do it with TVB?</font></h1>
#
# ---
#
# <p><div style="text-align: justify"><font size="4.5" face="time roman">The first thing we need to do, is to import the necessary TVB modules and some additional Python packages to perform the simulation and visualize our results.</font></div></p>

# %%
! pip install -U tvb-library
# Out:
# Requirement already up-to-date: tvb-library in /opt/app-root/lib/python3.6/site-packages (2.0.9)
# Requirement already satisfied, skipping upgrade: networkx in /opt/app-root/lib/python3.6/site-packages (from tvb-library) (2.4)
# Requirement already satisfied, skipping upgrade: numpy in /opt/app-root/lib/python3.6/site-packages (from tvb-library) (1.18.1)
# Requirement already satisfied, skipping upgrade: matplotlib in /opt/app-root/lib/python3.6/site-packages (from tvb-library) (3.1.3)
# Requirement already satisfied, skipping upgrade: scipy in /opt/app-root/lib/python3.6/site-packages (from tvb-library) (1.4.1)
# Requirement already satisfied, skipping upgrade: numba in /opt/app-root/lib/python3.6/site-packages (from tvb-library) (0.48.0)
# Requirement already satisfied, skipping upgrade: numexpr in /opt/app-root/lib/python3.6/site-packages (from tvb-library) (2.7.1)
# Requirement already satisfied, skipping upgrade: typing in /opt/app-root/lib/python3.6/site-packages (from tvb-library) (3.7.4.1)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /opt/app-root/lib/python3.6/site-packages (from networkx->tvb-library) (4.4.2)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /opt/app-root/lib/python3.6/site-packages (from matplotlib->tvb-library) (1.1.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /opt/app-root/lib/python3.6/site-packages (from matplotlib->tvb-library) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /opt/app-root/lib/python3.6/site-packages (from matplotlib->tvb-library) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /opt/app-root/lib/python3.6/site-packages (from matplotlib->tvb-library) (2.4.6)
# Requirement already satisfied, skipping upgrade: setuptools in /opt/app-root/lib/python3.6/site-packages (from numba->tvb-library) (46.0.0)
# Requirement already satisfied, skipping upgrade: llvmlite<0.32.0,>=0.31.0dev0 in /opt/app-root/lib/python3.6/site-packages (from numba->tvb-library) (0.31.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /opt/app-root/lib/python3.6/site-packages (from python-dateutil>=2.1->matplotlib->tvb-library) (1.14.0)
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/opt/app-root/bin/python3 -m pip install --upgrade pip' command.

# %%
# !wget https://zenodo.org/record/3688773/files/tvb-data.zip?download=1 -O $HOME/tvb_data.zip; \
    mkdir $HOME/tvb_data; unzip $HOME/tvb_data.zip -d $HOME/tvb_data; rm $HOME/tvb_data.zip; \
    cd $HOME/tvb_data; python setup.py install
# Out:
# --2020-10-19 09:22:46--  https://zenodo.org/record/3688773/files/tvb-data.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 355927948 (339M) [application/octet-stream]
# Saving to: ‘/opt/app-root/src/tvb_data.zip’
#
# 100%[======================================>] 355,927,948 44.9MB/s   in 7.3s
#
# 2020-10-19 09:22:53 (46.2 MB/s) - ‘/opt/app-root/src/tvb_data.zip’ saved [355927948/355927948]
#
# Archive:  /opt/app-root/src/tvb_data.zip
#   inflating: /opt/app-root/src/tvb_data/Jenkinsfile
#   inflating: /opt/app-root/src/tvb_data/LICENSE
#   inflating: /opt/app-root/src/tvb_data/MANIFEST.in
#   inflating: /opt/app-root/src/tvb_data/README.rst
#   inflating: /opt/app-root/src/tvb_data/setup.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/Default_Project.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/DH_20120806/DH_20120806_Connectivity.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/DH_20120806/DH_20120806_EEGLocations.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/DH_20120806/DH_20120806_ProjectionMatrix.mat
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/DH_20120806/DH_20120806_RegionMapping.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/DH_20120806/DH_20120806_Surface_Cortex.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/DH_20120806/DH_20120806_Surface_EEGCap.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/DH_20120806/DH_20120806_Surface_Face.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/DH_20120806/TVB-brain-activity.png
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/QL_20120814/QL_20120814_Connectivity.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/QL_20120814/QL_20120814_EEGLocations.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/QL_20120814/QL_20120814_ProjectionMatrix.mat
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/QL_20120814/QL_20120814_RegionMapping.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/QL_20120814/QL_20120814_Surface_Cortex.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/QL_20120814/QL_20120814_Surface_EEGCap.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/QL_20120814/QL_20120814_Surface_Face.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/QL_20120814/QL_BOLD_regiontimecourse.mat
#   inflating: /opt/app-root/src/tvb_data/tvb_data/berlinSubjects/readme.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/brco/tvb-brco.xml
#   inflating: /opt/app-root/src/tvb_data/tvb_data/brco/tvb-brco.xsd
#   inflating: /opt/app-root/src/tvb_data/tvb_data/connectivity/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/connectivity/connectivity_192.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/connectivity/connectivity_66.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/connectivity/connectivity_68.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/connectivity/connectivity_76.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/connectivity/connectivity_80.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/connectivity/connectivity_96.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/connectivity/connectivity_998.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/connectivity/paupau.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/dti_pipeline_toronto/ConnectivityTable_regions.xls
#   inflating: /opt/app-root/src/tvb_data/tvb_data/dti_pipeline_toronto/InputDTI_AnaSolodkin.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/dti_pipeline_toronto/InputDTI_Toronto.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/dti_pipeline_toronto/output_ConnectionCapacityMatrix.csv
#   inflating: /opt/app-root/src/tvb_data/tvb_data/dti_pipeline_toronto/output_ConnectionDistanceMatrix.csv
#   inflating: /opt/app-root/src/tvb_data/tvb_data/gifti/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/gifti/sample.cortex.gii
#   inflating: /opt/app-root/src/tvb_data/tvb_data/gifti/sample.time_series.gii
#   inflating: /opt/app-root/src/tvb_data/tvb_data/h5/Connectivity_74.h5
#   inflating: /opt/app-root/src/tvb_data/tvb_data/h5/TimeSeriesRegion.h5
#   inflating: /opt/app-root/src/tvb_data/tvb_data/h5/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/local_connectivity/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/local_connectivity/local_connectivity_16384.mat
#   inflating: /opt/app-root/src/tvb_data/tvb_data/local_connectivity/local_connectivity_80k.mat
#   inflating: /opt/app-root/src/tvb_data/tvb_data/macaque/README
#   inflating: /opt/app-root/src/tvb_data/tvb_data/macaque/connectivity_84.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/macaque/mapping_FS_84.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/macaque/prepare.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/macaque/regionMapping_147k_84.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/macaque/surface_147k.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/macaque/volumeMap_inF99.nii.gz
#   inflating: /opt/app-root/src/tvb_data/tvb_data/mouse/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/mouse/allen_2mm/Connectivity.h5
#   inflating: /opt/app-root/src/tvb_data/tvb_data/mouse/allen_2mm/ConnectivityAllen2mm.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/mouse/allen_2mm/RegionVolumeMapping.h5
#   inflating: /opt/app-root/src/tvb_data/tvb_data/mouse/allen_2mm/StructuralMRI.h5
#   inflating: /opt/app-root/src/tvb_data/tvb_data/mouse/allen_2mm/Volume.h5
#   inflating: /opt/app-root/src/tvb_data/tvb_data/mouse/calabrese/Connectivity_Calabrese.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/mouse/calabrese/Structural_MRI.nii
#   inflating: /opt/app-root/src/tvb_data/tvb_data/mouse/calabrese/Vol_Calabrese.nii
#   inflating: /opt/app-root/src/tvb_data/tvb_data/nifti/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/nifti/minimal.nii
#   inflating: /opt/app-root/src/tvb_data/tvb_data/nifti/minimal.nii.gz
#   inflating: /opt/app-root/src/tvb_data/tvb_data/nifti/time_series_152.nii.gz
#   inflating: /opt/app-root/src/tvb_data/tvb_data/nifti/volume_mapping/apply_mapping.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/nifti/volume_mapping/mapping_FS_76.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/nifti/volume_mapping/mapping_FS_84.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/nifti/volume_mapping/mapping_FS_88.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/obj/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/obj/eeg_cap.obj
#   inflating: /opt/app-root/src/tvb_data/tvb_data/obj/face_surface.obj
#   inflating: /opt/app-root/src/tvb_data/tvb_data/obj/scale_obj.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/obj/test_torus.obj
#   inflating: /opt/app-root/src/tvb_data/tvb_data/projectionMatrix/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/projectionMatrix/projection_eeg_248_surface_16k.npy
#   inflating: /opt/app-root/src/tvb_data/tvb_data/projectionMatrix/projection_eeg_62_surface_16k.mat
#   inflating: /opt/app-root/src/tvb_data/tvb_data/projectionMatrix/projection_eeg_63_surface_16k.npy
#   inflating: /opt/app-root/src/tvb_data/tvb_data/projectionMatrix/projection_eeg_65_surface_16k.npy
#   inflating: /opt/app-root/src/tvb_data/tvb_data/projectionMatrix/projection_meg_276_surface_16k.npy
#   inflating: /opt/app-root/src/tvb_data/tvb_data/projectionMatrix/projection_seeg_588_surface_16k.npy
#   inflating: /opt/app-root/src/tvb_data/tvb_data/regionMapping/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/regionMapping/regionMapping_16k_192.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/regionMapping/regionMapping_16k_76.bz2
#   inflating: /opt/app-root/src/tvb_data/tvb_data/regionMapping/regionMapping_16k_76.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/regionMapping/regionMapping_16k_76.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/regionMapping/regionMapping_80k_80.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/sensors/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/sensors/eeg_63.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/sensors/eeg_brainstorm_65.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/sensors/eeg_unitvector_62.txt.bz2
#   inflating: /opt/app-root/src/tvb_data/tvb_data/sensors/meg_151.txt.bz2
#   inflating: /opt/app-root/src/tvb_data/tvb_data/sensors/meg_248.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/sensors/meg_brainstorm_276.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/sensors/readme.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/sensors/seeg_39.txt.bz2
#   inflating: /opt/app-root/src/tvb_data/tvb_data/sensors/seeg_588.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/sensors/seeg_brainstorm_960.txt
#   inflating: /opt/app-root/src/tvb_data/tvb_data/sensors/view_h5_3d.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/cortex_16384.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/cortex_2x120k.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/cortex_80k.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/eeg_cap_rotated.h5
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/face_8614.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/inner_skull_4096.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/inner_skull_642.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/outer_skin_4096.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/outer_skull_4096.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/outer_skull_642.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/scalp_1082.zip
#   inflating: /opt/app-root/src/tvb_data/tvb_data/surfaceData/surface_fixes.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/tables/__init__.py
#   inflating: /opt/app-root/src/tvb_data/tvb_data/tables/nerf_int.npz
#   inflating: /opt/app-root/src/tvb_data/tvb_data/tables/psi.npz
# running install
# running bdist_egg
# running egg_info
# creating tvb_data.egg-info
# writing tvb_data.egg-info/PKG-INFO
# writing dependency_links to tvb_data.egg-info/dependency_links.txt
# writing top-level names to tvb_data.egg-info/top_level.txt
# writing manifest file 'tvb_data.egg-info/SOURCES.txt'
# reading manifest file 'tvb_data.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'tvb_data.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/tvb_data
# copying tvb_data/__init__.py -> build/lib/tvb_data
# creating build/lib/tvb_data/connectivity
# copying tvb_data/connectivity/__init__.py -> build/lib/tvb_data/connectivity
# creating build/lib/tvb_data/gifti
# copying tvb_data/gifti/__init__.py -> build/lib/tvb_data/gifti
# creating build/lib/tvb_data/h5
# copying tvb_data/h5/__init__.py -> build/lib/tvb_data/h5
# creating build/lib/tvb_data/local_connectivity
# copying tvb_data/local_connectivity/__init__.py -> build/lib/tvb_data/local_connectivity
# creating build/lib/tvb_data/mouse
# copying tvb_data/mouse/__init__.py -> build/lib/tvb_data/mouse
# creating build/lib/tvb_data/nifti
# copying tvb_data/nifti/__init__.py -> build/lib/tvb_data/nifti
# creating build/lib/tvb_data/obj
# copying tvb_data/obj/__init__.py -> build/lib/tvb_data/obj
# copying tvb_data/obj/scale_obj.py -> build/lib/tvb_data/obj
# creating build/lib/tvb_data/projectionMatrix
# copying tvb_data/projectionMatrix/__init__.py -> build/lib/tvb_data/projectionMatrix
# creating build/lib/tvb_data/regionMapping
# copying tvb_data/regionMapping/__init__.py -> build/lib/tvb_data/regionMapping
# creating build/lib/tvb_data/sensors
# copying tvb_data/sensors/__init__.py -> build/lib/tvb_data/sensors
# copying tvb_data/sensors/view_h5_3d.py -> build/lib/tvb_data/sensors
# creating build/lib/tvb_data/surfaceData
# copying tvb_data/surfaceData/__init__.py -> build/lib/tvb_data/surfaceData
# copying tvb_data/surfaceData/surface_fixes.py -> build/lib/tvb_data/surfaceData
# creating build/lib/tvb_data/tables
# copying tvb_data/tables/__init__.py -> build/lib/tvb_data/tables
# creating build/lib/tvb_data/brco
# copying tvb_data/brco/tvb-brco.xml -> build/lib/tvb_data/brco
# creating build/lib/tvb_data/dti_pipeline_toronto
# copying tvb_data/dti_pipeline_toronto/output_ConnectionCapacityMatrix.csv -> build/lib/tvb_data/dti_pipeline_toronto
# copying tvb_data/dti_pipeline_toronto/output_ConnectionDistanceMatrix.csv -> build/lib/tvb_data/dti_pipeline_toronto
# copying tvb_data/connectivity/connectivity_192.zip -> build/lib/tvb_data/connectivity
# copying tvb_data/connectivity/connectivity_66.zip -> build/lib/tvb_data/connectivity
# copying tvb_data/connectivity/connectivity_68.zip -> build/lib/tvb_data/connectivity
# copying tvb_data/connectivity/connectivity_76.zip -> build/lib/tvb_data/connectivity
# copying tvb_data/connectivity/connectivity_96.zip -> build/lib/tvb_data/connectivity
# copying tvb_data/connectivity/paupau.zip -> build/lib/tvb_data/connectivity
# copying tvb_data/gifti/sample.cortex.gii -> build/lib/tvb_data/gifti
# copying tvb_data/local_connectivity/local_connectivity_16384.mat -> build/lib/tvb_data/local_connectivity
# copying tvb_data/obj/eeg_cap.obj -> build/lib/tvb_data/obj
# copying tvb_data/obj/face_surface.obj -> build/lib/tvb_data/obj
# copying tvb_data/projectionMatrix/projection_eeg_62_surface_16k.mat -> build/lib/tvb_data/projectionMatrix
# copying tvb_data/projectionMatrix/projection_eeg_65_surface_16k.npy -> build/lib/tvb_data/projectionMatrix
# copying tvb_data/projectionMatrix/projection_meg_276_surface_16k.npy -> build/lib/tvb_data/projectionMatrix
# copying tvb_data/regionMapping/regionMapping_16k_192.txt -> build/lib/tvb_data/regionMapping
# copying tvb_data/regionMapping/regionMapping_16k_76.txt -> build/lib/tvb_data/regionMapping
# copying tvb_data/sensors/eeg_brainstorm_65.txt -> build/lib/tvb_data/sensors
# copying tvb_data/sensors/eeg_unitvector_62.txt.bz2 -> build/lib/tvb_data/sensors
# copying tvb_data/sensors/meg_151.txt.bz2 -> build/lib/tvb_data/sensors
# copying tvb_data/sensors/meg_brainstorm_276.txt -> build/lib/tvb_data/sensors
# copying tvb_data/sensors/seeg_39.txt.bz2 -> build/lib/tvb_data/sensors
# copying tvb_data/sensors/seeg_588.txt -> build/lib/tvb_data/sensors
# copying tvb_data/surfaceData/cortex_16384.zip -> build/lib/tvb_data/surfaceData
# copying tvb_data/surfaceData/face_8614.zip -> build/lib/tvb_data/surfaceData
# copying tvb_data/surfaceData/inner_skull_4096.zip -> build/lib/tvb_data/surfaceData
# copying tvb_data/surfaceData/outer_skin_4096.zip -> build/lib/tvb_data/surfaceData
# copying tvb_data/surfaceData/outer_skull_4096.zip -> build/lib/tvb_data/surfaceData
# copying tvb_data/surfaceData/scalp_1082.zip -> build/lib/tvb_data/surfaceData
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/tvb_data
# copying build/lib/tvb_data/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data
# creating build/bdist.linux-x86_64/egg/tvb_data/connectivity
# copying build/lib/tvb_data/connectivity/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data/connectivity
# copying build/lib/tvb_data/connectivity/connectivity_192.zip -> build/bdist.linux-x86_64/egg/tvb_data/connectivity
# copying build/lib/tvb_data/connectivity/connectivity_66.zip -> build/bdist.linux-x86_64/egg/tvb_data/connectivity
# copying build/lib/tvb_data/connectivity/connectivity_68.zip -> build/bdist.linux-x86_64/egg/tvb_data/connectivity
# copying build/lib/tvb_data/connectivity/connectivity_76.zip -> build/bdist.linux-x86_64/egg/tvb_data/connectivity
# copying build/lib/tvb_data/connectivity/connectivity_96.zip -> build/bdist.linux-x86_64/egg/tvb_data/connectivity
# copying build/lib/tvb_data/connectivity/paupau.zip -> build/bdist.linux-x86_64/egg/tvb_data/connectivity
# creating build/bdist.linux-x86_64/egg/tvb_data/gifti
# copying build/lib/tvb_data/gifti/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data/gifti
# copying build/lib/tvb_data/gifti/sample.cortex.gii -> build/bdist.linux-x86_64/egg/tvb_data/gifti
# creating build/bdist.linux-x86_64/egg/tvb_data/h5
# copying build/lib/tvb_data/h5/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data/h5
# creating build/bdist.linux-x86_64/egg/tvb_data/local_connectivity
# copying build/lib/tvb_data/local_connectivity/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data/local_connectivity
# copying build/lib/tvb_data/local_connectivity/local_connectivity_16384.mat -> build/bdist.linux-x86_64/egg/tvb_data/local_connectivity
# creating build/bdist.linux-x86_64/egg/tvb_data/mouse
# copying build/lib/tvb_data/mouse/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data/mouse
# creating build/bdist.linux-x86_64/egg/tvb_data/nifti
# copying build/lib/tvb_data/nifti/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data/nifti
# creating build/bdist.linux-x86_64/egg/tvb_data/obj
# copying build/lib/tvb_data/obj/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data/obj
# copying build/lib/tvb_data/obj/scale_obj.py -> build/bdist.linux-x86_64/egg/tvb_data/obj
# copying build/lib/tvb_data/obj/eeg_cap.obj -> build/bdist.linux-x86_64/egg/tvb_data/obj
# copying build/lib/tvb_data/obj/face_surface.obj -> build/bdist.linux-x86_64/egg/tvb_data/obj
# creating build/bdist.linux-x86_64/egg/tvb_data/projectionMatrix
# copying build/lib/tvb_data/projectionMatrix/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data/projectionMatrix
# copying build/lib/tvb_data/projectionMatrix/projection_eeg_62_surface_16k.mat -> build/bdist.linux-x86_64/egg/tvb_data/projectionMatrix
# copying build/lib/tvb_data/projectionMatrix/projection_eeg_65_surface_16k.npy -> build/bdist.linux-x86_64/egg/tvb_data/projectionMatrix
# copying build/lib/tvb_data/projectionMatrix/projection_meg_276_surface_16k.npy -> build/bdist.linux-x86_64/egg/tvb_data/projectionMatrix
# creating build/bdist.linux-x86_64/egg/tvb_data/regionMapping
# copying build/lib/tvb_data/regionMapping/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data/regionMapping
# copying build/lib/tvb_data/regionMapping/regionMapping_16k_192.txt -> build/bdist.linux-x86_64/egg/tvb_data/regionMapping
# copying build/lib/tvb_data/regionMapping/regionMapping_16k_76.txt -> build/bdist.linux-x86_64/egg/tvb_data/regionMapping
# creating build/bdist.linux-x86_64/egg/tvb_data/sensors
# copying build/lib/tvb_data/sensors/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data/sensors
# copying build/lib/tvb_data/sensors/view_h5_3d.py -> build/bdist.linux-x86_64/egg/tvb_data/sensors
# copying build/lib/tvb_data/sensors/eeg_brainstorm_65.txt -> build/bdist.linux-x86_64/egg/tvb_data/sensors
# copying build/lib/tvb_data/sensors/eeg_unitvector_62.txt.bz2 -> build/bdist.linux-x86_64/egg/tvb_data/sensors
# copying build/lib/tvb_data/sensors/meg_151.txt.bz2 -> build/bdist.linux-x86_64/egg/tvb_data/sensors
# copying build/lib/tvb_data/sensors/meg_brainstorm_276.txt -> build/bdist.linux-x86_64/egg/tvb_data/sensors
# copying build/lib/tvb_data/sensors/seeg_39.txt.bz2 -> build/bdist.linux-x86_64/egg/tvb_data/sensors
# copying build/lib/tvb_data/sensors/seeg_588.txt -> build/bdist.linux-x86_64/egg/tvb_data/sensors
# creating build/bdist.linux-x86_64/egg/tvb_data/surfaceData
# copying build/lib/tvb_data/surfaceData/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data/surfaceData
# copying build/lib/tvb_data/surfaceData/surface_fixes.py -> build/bdist.linux-x86_64/egg/tvb_data/surfaceData
# copying build/lib/tvb_data/surfaceData/cortex_16384.zip -> build/bdist.linux-x86_64/egg/tvb_data/surfaceData
# copying build/lib/tvb_data/surfaceData/face_8614.zip -> build/bdist.linux-x86_64/egg/tvb_data/surfaceData
# copying build/lib/tvb_data/surfaceData/inner_skull_4096.zip -> build/bdist.linux-x86_64/egg/tvb_data/surfaceData
# copying build/lib/tvb_data/surfaceData/outer_skin_4096.zip -> build/bdist.linux-x86_64/egg/tvb_data/surfaceData
# copying build/lib/tvb_data/surfaceData/outer_skull_4096.zip -> build/bdist.linux-x86_64/egg/tvb_data/surfaceData
# copying build/lib/tvb_data/surfaceData/scalp_1082.zip -> build/bdist.linux-x86_64/egg/tvb_data/surfaceData
# creating build/bdist.linux-x86_64/egg/tvb_data/tables
# copying build/lib/tvb_data/tables/__init__.py -> build/bdist.linux-x86_64/egg/tvb_data/tables
# creating build/bdist.linux-x86_64/egg/tvb_data/brco
# copying build/lib/tvb_data/brco/tvb-brco.xml -> build/bdist.linux-x86_64/egg/tvb_data/brco
# creating build/bdist.linux-x86_64/egg/tvb_data/dti_pipeline_toronto
# copying build/lib/tvb_data/dti_pipeline_toronto/output_ConnectionCapacityMatrix.csv -> build/bdist.linux-x86_64/egg/tvb_data/dti_pipeline_toronto
# copying build/lib/tvb_data/dti_pipeline_toronto/output_ConnectionDistanceMatrix.csv -> build/bdist.linux-x86_64/egg/tvb_data/dti_pipeline_toronto
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/connectivity/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/gifti/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/h5/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/local_connectivity/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/mouse/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/nifti/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/obj/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/obj/scale_obj.py to scale_obj.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/projectionMatrix/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/regionMapping/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/sensors/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/sensors/view_h5_3d.py to view_h5_3d.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/surfaceData/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/surfaceData/surface_fixes.py to surface_fixes.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tvb_data/tables/__init__.py to __init__.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying tvb_data.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying tvb_data.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying tvb_data.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying tvb_data.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/tvb_data-2.0.2-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing tvb_data-2.0.2-py3.6.egg
# Removing /opt/app-root/lib/python3.6/site-packages/tvb_data-2.0.2-py3.6.egg
# Copying tvb_data-2.0.2-py3.6.egg to /opt/app-root/lib/python3.6/site-packages
# tvb-data 2.0.2 is already the active version in easy-install.pth
#
# Installed /opt/app-root/lib/python3.6/site-packages/tvb_data-2.0.2-py3.6.egg
# Processing dependencies for tvb-data==2.0.2
# Finished processing dependencies for tvb-data==2.0.2

# %%
# Online visualization.
# %pylab nbagg

# Import tvb library.
from tvb.simulator.lab import *
import tvb.datatypes.projections as projections

# Import a bunch of stuff to ease command line usage.
import os
import numpy as np
import time as tm
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <h1><font size="6" face="arial" color="black">1. Build a virtual epileptic patient</font></h1>
# <br>
# <p><div style="text-align: justify"><font size="4.5" face="time roman">In the following, we will model a random patient suffering from a <b>bilateral temporal lobe epilepsy (TLE)</b> using the Default TVB Subject dataset.</font></div></p> <br>

# %% [markdown]
# <br><p><div style="text-align: justify"><font size="4.5" face="time roman">The basic simulation of TVB consists of <b>5 main components</b>. Each of these components is an object within TVB:</font></div></p>
#
# <h2><font size="5"face="arial" color="black"> 1.1 Anatomical Structural Connectivity</font></h2>
#
# <p><div style="text-align: justify"><font size="4.5" face="time roman">We start with loading and visualizing the structural connectivity matrix of the patient.</font></div></p>

# %%
# Initialise a Connectivity.
con = connectivity.Connectivity.from_file()   
nregions = len(con.areas)                                  #number of regions
con.weights = con.weights - con.weights * np.eye(nregions) #remove self-connections
con.weights = con.weights / np.abs(con.weights.max())      #normalize
con.speed = np.array(np.inf)                                         #set the conduction speed to infinity (no time delays)
con.configure()

# Visualization.
figure(figsize=(8,8))
imshow(con.weights, interpolation='nearest', aspect='equal', cmap='jet')
title('Patient - Structural Connectome', fontsize=14)
cb=colorbar(shrink=0.8, ticks=[0, .5, 1])
cb.set_label('weights')
xticks(range(0, nregions), con.region_labels, fontsize=6, rotation=90)
yticks(range(0, nregions), con.region_labels, fontsize=6)
show()
# Out:
# WARNING  File 'hemispheres' not found in ZIP.

# %% [markdown]
# <h2><font size="5" face="arial" color="black"> 1.2 Model</font></h2>
#
# <p><div style="text-align: justify"><font size="4.5" face="time roman">In order to model epilepsy, we choose the <b>Epileptor</b> which is a phenomenological neural mass model able to realistically reproduce <b>epileptic seizure dynamics</b> such as recorded with intracranial EEG electrodes (see <b>Jirsa et al., Brain 2014</b>):</font></div></p>
#
# \begin{eqnarray}
#     \dot{x}_{1} &=& y_{1} - f_{1}(x_{1}, x_{2}) - z + I_{ext_{1}}\\
#     \dot{y}_{1} &=& 1 - 5x_{1}^{2} - y_{1}\\
#     \dot{z} &=& \dfrac{1}{\tau_{0}} \ (4 (x_{1} - \color{blue}{x_{0}}) - z)\\
#     \dot{x}_{2} &=& - y_{2} + x_{2} - x_{2}^{3} + I_{ext_{2}} + 0.002g(x_{1}) - 0.3 (z - 3.5)\\
#     \dot{y}_{2} &=& \dfrac{1}{\tau_{2}} \ (-y_{2} + f_{2}(x_{2}))\\
# \end{eqnarray}
#
# <p><div style="text-align: justify"><font size="4.5" face="time roman">where $\tau_{0}=2857$, $I_{ext_{1}}=3.1$, $I_{ext_{2}}=0.45$. The parameter $\pmb{x_{0}}$ controls the degree of <b>epileptogenicity</b> (or excitability) of the node:
#
# <br>
# <ul><li>if $\pmb{x_{0} \geqslant x_{0, c}}$, the Epileptor can trigger seizures and is said <b>epileptogenic</b>,</li>
#
# <br><li>inversely, if $\pmb{x_{0} < x_{0, c}}$, the Epileptor does not trigger seizure and is said <b>not epileptogenic</b> (or in its "healthy" equilibrium state).</li></ul>
#
#
# <br>See equations page 8 in Jirsa et al. (2014) for more details on the model.</font></div></p><br>

# %%
# Initialise a Model.
epi = models.Epileptor(Ks=np.array(1.), r=np.array(0.00015)) # in Jirsa et al. (2014): r = 1/ \tau_0

# Set initial conditions in fixed point.
epi.state_variable_range["x1"] = [-5, -3]
epi.state_variable_range["y1"] = [-50, -50]
epi.state_variable_range["z"] = [4., 6.]
epi.state_variable_range["x2"] = [-1.1, 1.1]
epi.state_variable_range["y2"] = [0.001, 0.01]

# %% [markdown]
# <p><div style="text-align: justify"><font size="4.5" face="time roman">We can refine the network pathology of the patient by including the clinical hypothesis about its <b>Epileptogenic Network</b>. To this end, we define a <b>spatial map of epileptogenicity</b> where each network's node <i>i</i> is characterized by an excitability value $\pmb{x_{0,i}}$, which quantifies the ability of the node to trigger a seizure.
# <br>We set:
# <ul>
# <li>the hippocampus (rHC, region 9 and lHC, region 47) as well as the amydala (rAMYG, region 2 and lAMYG, region 40)
# as part of the <b>Epileptogenic Zone (EZ)</b>, with an epileptogenicity parameter value $\pmb{x_{0,i}}$ equal to <b>-1.4</b> for the rHC and <b>-1.6</b> for the lHC and l-rAMYG,</li>
# <li>we also add two lesser epileptogenic regions: the parahippocampal (lPHC, region 62) and the temporal pole (lTPOL, region 70) as part of the <b>Propagation Zone (PZ)</b>, with an epileptogenicity parameter value $\pmb{x_{0,i}}$ equal to <b>-1.7</b> and <b>-1.8</b>, respectively,</li>
# <li>and all the other regions (or <b>Non-Involved Zone, NIZ</b>) are set to <b>-2.6</b>.</li>
# </ul>

# %%
# Define a heatmap.
epi.x0 = np.ones(nregions) * (-2.6)           #NIZ
epi.x0[[9]] = np.ones((1)) * (-1.4)           #EZ 
epi.x0[[47, 2, 40]] = np.ones((3)) * (-1.6)   #EZ 
epi.x0[[62]] = np.ones((1)) * (-1.7)          #PZ 
epi.x0[[70]] = np.ones((1)) * (-1.8)          #PZ

# %% [markdown]
# <h2><font size="5"face="arial" color="black"> 2.3 Coupling function</font></h2>
#
# <p><div style="text-align: justify"><font size="4.5" face="time roman">We couple the Epileptors by <b>permittivity coupling</b> (see Proix et al., 2014), which quantifies the influence of neuronal fast discharges $x_{1,j}$ of a remote region $j$ on the local slow permittivity variable $z_{i}$ of region $i$ via a linear <b>difference coupling</b> function, allowing the spread of the seizure through the network by recruiting regions that are not in the EZ.</font></div></p>
#
# \begin{eqnarray}
#     \dot{x}_{1,i} &=& y_{1,i} - f_{1}(x_{1,i}, x_{2,i}) - z_{i} + I_{ext_{1}}\\
#     \dot{y}_{1,i} &=& 1 - 5x_{1,i}^{2} - y_{1,i}\\
#     \dot{z}_{i} &=& \dfrac{1}{\tau_{0}} \ (4 (x_{1,i} - x_{0,i}) - z_{i} \color{red}{- K_{s} * G \ \sum_{j=1}^{N}C_{ij}(x_{1,j} - x_{1,i}))}\\
#     \dot{x}_{2,i} &=& - y_{2,i} + x_{2,i} - x_{2,i}^{3} + I_{ext_{2}} + 0.002g(x_{1,i}) - 0.3 (z_{i} - 3.5)\\
#     \dot{y}_{2,i} &=& \dfrac{1}{\tau_{2}} \ (-y_{2,i} + f_{2}(x_{2,i}))\\
# \end{eqnarray}

# %%
# Initialise a Coupling function.
G = np.array(-0.25)      #global (long-range) coupling strength
con_coupling = coupling.Difference(a=G)

# %% [markdown]
# <h2><font size="5"face="arial" color="black"> 2.4 Integrator</font></h2>
#
# <p><div style="text-align: justify"><font size="4.5" face="time roman">We employ a standard <b>Heun method</b> with an integration time step of <b>0.05</b>. <b>Additive white Gaussian noise</b> is introduced in the state-variables $\pmb{x_{2,i}}$ and $\pmb{y_{2,i}}$ with 0 mean and variance <b>0.00025</b>.</font></div></p>

# %%
# Initialise an Integrator scheme.
dt = 0.05               #integration steps [ms]
nsigma = 0.00025        #standard deviation of the noise

hiss = noise.Additive(nsig=np.array([0., 0., 0., nsigma, nsigma, 0.])) 
heunint = integrators.HeunStochastic(dt=dt, noise=hiss)

# %% [markdown]
# <h2><font size="5"face="arial" color="black"> 2.5 Monitors</font></h2>
#
# <p><div style="text-align: justify"><font size="4.5" face="time roman">Here, we will select (1) a simple data reduction monitor and (2) a biophysical measurement process to relate the simulated neural activity to recent epilepsy studies:
#
# <ol type="1">
# <li>the <b>TemporalAverage</b> monitor averages over a time window of length <i>period</i> returning one time point every <i>period</i> ms,</li>
# <li>the <b>iEEG</b> monitor generates SEEG recordings.</li>
# </ol>
# </font></div></p>

# %%
# Initialise some Monitors with period in physical time.
#Temporal Average
mon_tavg = monitors.TemporalAverage(period=1) #in ms

#SEEG
#Load the default region mapping
rm = region_mapping.RegionMapping.from_file()

mon_seeg = monitors.iEEG.from_file(
            projection_fname=os.path.join(os.getcwd(),"data","projection_seeg_588_surface_16k.npy"),
            region_mapping=rm,
            period=1.)

what_to_watch = (mon_tavg, mon_seeg)

# %% [markdown]
# ***
#
# <h1 align="center"><font size="6"face="arial" color="black">Go! Simulate</font></h1>
#
# <p><div style="text-align: justify"><font size="4.5" face="time roman">We can then configure and run the <b>Simulator</b>.</font></div></p>

# %%
# Initialise the Simulator.
sim = simulator.Simulator(connectivity=con,
                          conduction_speed=np.float(con.speed),
                          model=epi,
                          coupling=con_coupling,
                          integrator=heunint,
                          monitors=what_to_watch)

sim.configure()
# Out:
#    INFO  Projection configured gain shape (588, 76)
# <table>
# <h3>Simulator</h3>
# <thead><tr><th></th><th style="text-align:left;width:40%">value</th></tr></thead>
# <tbody>
# <tr><td>Type</td><td style="text-align:left;"><pre>Simulator</pre></td>
# <tr><td>conduction_speed</td><td style="text-align:left;"><pre>inf</pre></td>
# <tr><td>connectivity</td><td style="text-align:left;"><pre>Connectivity gid: d86b7f4b-e6c0-4b3d-a7a8-e33320120f48</pre></td>
# <tr><td>coupling</td><td style="text-align:left;"><pre>Difference gid: 1a402fa8-c524-4bae-8c60-f85077bc669e</pre></td>
# <tr><td>gid</td><td style="text-align:left;"><pre>UUID('8fd1650e-5bea-4a92-bde7-48925c518da6')</pre></td>
# <tr><td>initial_conditions</td><td style="text-align:left;"><pre>None</pre></td>
# <tr><td>integrator</td><td style="text-align:left;"><pre>HeunStochastic gid: b16ea1cb-b575-4959-90dd-e0131db9df38</pre></td>
# <tr><td>model</td><td style="text-align:left;"><pre>Epileptor gid: 9d7b9fa9-8e99-4120-aa27-e4aa5a607b35</pre></td>
# <tr><td>monitors</td><td style="text-align:left;"><pre>(<tvb.simulator.monitors.TemporalAverage object at 0x7f5a6454e6d8>, <tvb.simulator.monitors.iEEG object at 0x7f5a645262e8>)</pre></td>
# <tr><td>simulation_length</td><td style="text-align:left;"><pre>1000.0</pre></td>
# <tr><td>stimulus</td><td style="text-align:left;"><pre>None</pre></td>
# <tr><td>surface</td><td style="text-align:left;"><pre>None</pre></td>
# <tr><td>title</td><td style="text-align:left;"><pre>Simulator gid: 8fd1650e-5bea-4a92-bde7-48925c518da6</pre></td>
# </tbody></table>

# %%
# Starting simulation.
print("Starting simulation...")
tic = tm.time()
(ttavg, tavg), (tseeg, seeg) = sim.run(simulation_length=10000) 

# Finished simulation. 
print("Finished simulation.")
print("execute for" + str(tm.time()-tic))
# Out:
# Starting simulation...
# Finished simulation.
# execute for123.79825329780579

# %% [markdown]
# ***
#
# <h1 align="center"><font size="6"face="arial" color="black">Visualize our simulation</font></h1>
#
# <p><div style="text-align: justify"><font size="4.5" face="time roman">And finally, we can look at the results of our simulation in terms of time series:</font></div></p>

# %%
# Normalize the time series to have nice plots.
tavg /= (np.max(tavg,0) - np.min(tavg,0 ))
tavg -= np.mean(tavg, 0)
seeg /= (np.max(seeg,0) - np.min(seeg, 0))
seeg -= np.mean(seeg, 0)

# %%
# Plot source activity time series.
fig, ax  = subplots(figsize=(8,8))

ax.plot(ttavg[:], tavg[:, 0, :, 0] + np.r_[:nregions], 'k', alpha=0.1)
title('Epileptors time series', fontsize=15)
xlabel('Time [ms]', fontsize=15)
yticks(np.arange(len(con.region_labels)), con.region_labels, fontsize=6)

EZs = [9, 47, 2, 40]
for iez, ez in enumerate(EZs):
    ax.plot(ttavg[:], tavg[:, 0, EZs[iez], 0] + EZs[iez], 'r')
    ax.get_yticklabels()[EZs[iez]].set_color('r')

PZs = [62, 70]
for ipz, pz in enumerate(PZs):
    ax.plot(ttavg[:], tavg[:, 0, PZs[ipz], 0] + PZs[ipz], 'b')
    ax.get_yticklabels()[PZs[ipz]].set_color('b')
    
show()

# %%
# Plot the selected SEEG sensors recordings.
#SEEG sensors 
contacts = np.r_[np.arange(27, 36), np.arange(321, 330), #B(rHC) - B'(lHC)
                 np.arange(36, 45), np.arange(330, 339), #C(rHC) - C'(lHC)
                 np.arange(18, 27), np.arange(312, 321), #NA(rA) - NA'(lA)
                 np.arange(339, 348), #GPH'(lPHC)
                 np.arange(294, 303), #TP'(lTP)
                 np.arange(303, 312) # TB' (lTl basalis)
                  ]

figure(figsize=(10,10))
plot(tseeg[:], seeg[:, 0, contacts, 0] + np.r_[:len(contacts)], 'b')
yticks(np.r_[:len(contacts)], mon_seeg.sensors.labels[contacts], fontsize=6)
title('SEEG', fontsize=15)
xlabel('Time [ms]', fontsize=15)
show()

# %% [markdown]
# <h1><font size="6" face="arial" color="##2C5453">That is all folks</font></h1>
#
# ***
#
# <p><div style="text-align: justify"><font size="4.5" face="time roman">We hope this has been a useful tutorial and welcome any comments or questions.</font></div></p>
#
# <br><p><div style="text-align: justify"><font size="4.5" face="time roman"><u>References</u></font></div></p>
# * Jirsa et al., 2014:
#
# Jirsa, V. K.; Stacey, W. C.; Quilichini, P. P.; Ivanov, A. I.; Bernard, C. <b>On the nature of seizure dynamics</b>. <i>Brain</i>, 2014; 137: 2210–30.
#
# * Proix et al., 2014:
#
# Proix, T; Bartolomei, F.; Chauvel, P.; Bernard, C.; Jirsa, V. K. <b>Permittivity coupling across brain regions determines seizure recruitment in partial epilepsy</b>. <i>J of Neurosci</i>, 2014; 34(45):15009 –15021.
